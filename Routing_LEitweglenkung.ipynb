# %%
# open xlsx File 
#
file = 'data/anhang_routing-tabelle-festnetzmobiltelefonieausgabe2019-2.xlsx'


import pandas as pd
data = pd.ExcelFile("data/anhang_routing-tabelle-festnetzmobiltelefonieausgabe2019-2.xlsx")

my_sheet = 'Routing Number Index'
routing_index = pd.read_excel(file, sheet_name = my_sheet)
print(routing_index)

gemeinden = pd.read_excel(file, index_col=None, na_values=['NA'], sheet_name = 'Gemeinden', usecols = "A,B,C,D,E,F,G,H,I,J,K")
print(gemeinden)
# Out:
#      Routing Nummer                    Alarmzentrale  \
# 0    (0)989 112 500  Kantonale Notrufzentrale (KNZ)
# 1    (0)989 112 510  Kantonspolizei Appenzell A. Rh.
# 2    (0)989 112 520  Kantonspolizei Appenzell I. Rh.
# 3    (0)989 112 530         Polizei Basel-Landschaft
# 4    (0)989 112 540       Kantonspolizei Basel-Stadt
# ..              ...                              ...
# 229  (0)989 147 730                    pro juventute
# 230  (0)989 147 740                    pro juventute
# 231  (0)989 147 750                    pro juventute
# 232  (0)989 147 901                    pro juventute
# 233  (0)989 147 902                    pro juventute
#
#          Alarmzentrale Zusatz          Strasse Nummer   PLZ        Ort  \
# 0                         NaN     Tellistrasse     85  5001      Aarau
# 1    Kantonale Notrufzentrale  Schützenstrasse      1  9100    Herisau
# 2                         NaN     Unteres Ziel     20  9050  Appenzell
# ...
